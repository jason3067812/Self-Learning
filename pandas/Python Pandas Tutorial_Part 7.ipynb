# %% [markdown]
# ## Add/Remove Rows and Columns From DataFrames

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 以下為 Python dictionary 各種寫法

# %%
person = {"first": "Corey",
          "last": "Schafer",
          "email": "CoreySchafer@gmail.com"}

# %%
people = {"first": ["Corey"],
          "last": ["Schafer"],
          "email": ["CoreySchafer@gmail.com"]}

# %%
people = {"first": ["Corey", "Jane", "John"],
          "last": ["Schafer", "Doe", "Doe"],
          "email": ["CoreySchafer@gmail.com", "JaneDoe@gmail.com", "JohnDoe@gmail.com"]}

# %%
df = pd.DataFrame(people) # pandas 可以直接讀取 dictionary 格式

# %%
df
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@gmail.com
# 2   John      Doe       JohnDoe@gmail.com

# %%
df.sort_values(by=['last']) # sort_values 針對列索引資料排序(default ascending=True) 優先第一個英文字母順序 次優先字串長度 若都相同則會比第二個英文字母順序... 以此類推 若為數字則由小到大 (此結果未存回原資料)
# Out:
#    first     last                   email
# 1   Jane      Doe       JaneDoe@gmail.com
# 2   John      Doe       JohnDoe@gmail.com
# 0  Corey  Schafer  CoreySchafer@gmail.com

# %%
df.sort_values(by=['last', 'first']) # 當複數個列索引同時排列 先排好的不會被後面排的影響 也就是說後面的 'first' 想改變 'last' 的順序已經不可能 (此結果未存回原資料)
# Out:
#    first     last                   email
# 1   Jane      Doe       JaneDoe@gmail.com
# 2   John      Doe       JohnDoe@gmail.com
# 0  Corey  Schafer  CoreySchafer@gmail.com

# %%
df.sort_values(by=['last'], ascending=False) # ascending 升冪排序(pandas 中的升冪為向下 若為 False 則向上) 若為 False 則排序後面的元素會在前面 (此結果未存回原資料)
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@gmail.com
# 2   John      Doe       JohnDoe@gmail.com

# %%
df.sort_values(by=['last', 'first'], ascending=False) # 因為在 'last' 中排序優先度相同都是 'Doe' 但是在 'first' 中 Jane 的排序優先度應該大於 John 又因為 ascending=False 所以要把正常來說應該排在後面的元素排在前面 (此結果未存回原資料)
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 2   John      Doe       JohnDoe@gmail.com
# 1   Jane      Doe       JaneDoe@gmail.com

# %%
people = {"first": ["Corey", "Jane", "John", "Adam"],
          "last": ["Schafer", "Doe", "Doe", "Doe"],
          "email": ["CoreySchafer@gmail.com", "JaneDoe@gmail.com", "JohnDoe@gmail.com", "A@gmail.com"]}

# %%
df2 = pd.DataFrame(people)

# %%
df2
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@gmail.com
# 2   John      Doe       JohnDoe@gmail.com
# 3   Adam      Doe             A@gmail.com

# %%
df2.sort_values(by=['last']) # (此結果未存回原資料)
# Out:
#    first     last                   email
# 1   Jane      Doe       JaneDoe@gmail.com
# 2   John      Doe       JohnDoe@gmail.com
# 3   Adam      Doe             A@gmail.com
# 0  Corey  Schafer  CoreySchafer@gmail.com

# %%
df2.sort_values(by=['last', 'first']) # (此結果未存回原資料)
# Out:
#    first     last                   email
# 3   Adam      Doe             A@gmail.com
# 1   Jane      Doe       JaneDoe@gmail.com
# 2   John      Doe       JohnDoe@gmail.com
# 0  Corey  Schafer  CoreySchafer@gmail.com

# %%
df2.sort_values(by=['last'], ascending=False) # (此結果未存回原資料)
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@gmail.com
# 2   John      Doe       JohnDoe@gmail.com
# 3   Adam      Doe             A@gmail.com

# %%
df2.sort_values(by=['last', 'first'], ascending=[False, True], inplace=True) # 與前面用法相似但是這邊分別指定不同列索引的 ascending 布靈值 且寫入原資料中使改變生效

# %%
df2.sort_index() # 排列行索引 直接將被改變排序的資料轉換回原始資料 (注意:這邊會直接再寫入資料並儲存)
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@gmail.com
# 2   John      Doe       JohnDoe@gmail.com
# 3   Adam      Doe             A@gmail.com

# %%
df2 # 如上述
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 3   Adam      Doe             A@gmail.com
# 1   Jane      Doe       JaneDoe@gmail.com
# 2   John      Doe       JohnDoe@gmail.com

# %%
df2['last'].sort_values() # 另一種指定列索引處理排序的方式 (此結果未存回原資料)
# Out:
# 3        Doe
# 1        Doe
# 2        Doe
# 0    Schafer
# Name: last, dtype: object

# %%
public_df = pd.read_csv('../pandas_dataset/developer_survey_2020/survey_results_public.csv')
schema_df = pd.read_csv('../pandas_dataset/developer_survey_2020/survey_results_schema.csv')

# %%
pd.set_option('display.max_columns', 100) #設定顯示 column 數量
pd.set_option('display.max_rows', 100) #設定顯示 row 數量

# %%
public_df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
#      CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# 0   European Euro            EUR   Microsoft SQL Server
# 1  Pound sterling            GBP                    NaN
# 2             NaN            NaN                    NaN
# 3    Albanian lek            ALL                    NaN
# 4             NaN            NaN       MySQL;PostgreSQL
#
#                           DatabaseWorkedWith  \
# 0  Elasticsearch;Microsoft SQL Server;Oracle
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4              MySQL;PostgreSQL;Redis;SQLite
#
#                                              DevType  \
# 0  Developer, desktop or enterprise applications;...
# 1            Developer, full-stack;Developer, mobile
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                              NaN
# 3  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Employed full-time
# 2                                                NaN
# 3                                                NaN
# 4                                 Employed full-time
#
#                       Ethnicity Gender  \
# 0  White or of European descent    Man
# 1                           NaN    NaN
# 2                           NaN    NaN
# 3  White or of European descent    Man
# 4  White or of European descent    Man
#
#                                           JobFactors                 JobSat  \
# 0  Languages, frameworks, and other technologies ...     Slightly satisfied
# 1                                                NaN      Very dissatisfied
# 2                                                NaN                    NaN
# 3  Flex time or a flexible schedule;Office enviro...  Slightly dissatisfied
# 4                                                NaN                    NaN
#
#                                              JobSeek  \
# 0       I am not interested in new job opportunities
# 1       I am not interested in new job opportunities
# 2                                                NaN
# 3  I’m not actively looking, but I am open to new...
# 4                                                NaN
#
#      LanguageDesireNextYear        LanguageWorkedWith  \
# 0    C#;HTML/CSS;JavaScript    C#;HTML/CSS;JavaScript
# 1              Python;Swift          JavaScript;Swift
# 2  Objective-C;Python;Swift  Objective-C;Python;Swift
# 3                       NaN                       NaN
# 4           Java;Ruby;Scala         HTML/CSS;Ruby;SQL
#
#              MiscTechDesireNextYear MiscTechWorkedWith  \
# 0                 .NET Core;Xamarin     .NET;.NET Core
# 1  React Native;TensorFlow;Unity 3D       React Native
# 2                               NaN                NaN
# 3                               NaN                NaN
# 4                      Ansible;Chef            Ansible
#
#              NEWCollabToolsDesireNextYear  \
# 0  Microsoft Teams;Microsoft Azure;Trello
# 1                            Github;Slack
# 2                                     NaN
# 3                                     NaN
# 4   Github;Google Suite (Docs, Meet, etc)
#
#                             NEWCollabToolsWorkedWith NEWDevOps  \
# 0       Confluence;Jira;Slack;Microsoft Azure;Trello        No
# 1                Confluence;Jira;Github;Gitlab;Slack       NaN
# 2                                                NaN       NaN
# 3                                                NaN        No
# 4  Confluence;Jira;Github;Slack;Google Suite (Doc...       NaN
#
#         NEWDevOpsImpt                           NEWEdImpt  \
# 0  Somewhat important                    Fairly important
# 1                 NaN                    Fairly important
# 2                 NaN                                 NaN
# 3                 NaN  Not at all important/not necessary
# 4                 NaN                      Very important
#
#                                           NEWJobHunt NEWJobHuntResearch  \
# 0                                                NaN                NaN
# 1                                                NaN                NaN
# 2                                                NaN                NaN
# 3  Curious about other opportunities;Wanting to w...                NaN
# 4                                                NaN                NaN
#
#         NEWLearn NEWOffTopic NEWOnboardGood NEWOtherComms  \
# 0    Once a year    Not sure            NaN            No
# 1    Once a year    Not sure            NaN            No
# 2  Once a decade         NaN            NaN            No
# 3    Once a year    Not sure            Yes           Yes
# 4    Once a year          No            NaN           Yes
#
#                                          NEWOvertime  \
# 0                   Often: 1-2 days per week or more
# 1                                                NaN
# 2                                                NaN
# 3  Occasionally: 1-2 days per quarter but less th...
# 4                                                NaN
#
#                                  NEWPurchaseResearch      NEWPurpleLink  \
# 0  Start a free trial;Ask developers I know/work ...             Amused
# 1                                                NaN             Amused
# 2                                                NaN                NaN
# 3                                                NaN                NaN
# 4  Start a free trial;Ask developers I know/work ...  Hello, old friend
#
#                                           NEWSOSites  \
# 0   Stack Overflow (public Q&A for anyone who codes)
# 1  Stack Overflow (public Q&A for anyone who code...
# 2   Stack Overflow (public Q&A for anyone who codes)
# 3  Stack Overflow (public Q&A for anyone who code...
# 4  Stack Overflow (public Q&A for anyone who code...
#
#                                             NEWStuck        OpSys  \
# 0  Visit Stack Overflow;Go for a walk or other ph...      Windows
# 1  Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 2                                                NaN  Linux-based
# 3                                                NaN  Linux-based
# 4  Call a coworker or friend;Visit Stack Overflow...      Windows
#
#                     OrgSize  \
# 0          2 to 9 employees
# 1  1,000 to 4,999 employees
# 2                       NaN
# 3        20 to 99 employees
# 4                       NaN
#
#                               PlatformDesireNextYear  \
# 0     Android;iOS;Kubernetes;Microsoft Azure;Windows
# 1                         iOS;Kubernetes;Linux;MacOS
# 2                                                NaN
# 3                                                NaN
# 4  Docker;Google Cloud Platform;Heroku;Linux;Windows
#
#                PlatformWorkedWith                      PurchaseWhat  \
# 0                         Windows                               NaN
# 1                             iOS     I have little or no influence
# 2                             NaN                               NaN
# 3                             NaN  I have a great deal of influence
# 4  AWS;Docker;Linux;MacOS;Windows                               NaN
#
#                  Sexuality SOAccount           SOComm  \
# 0  Straight / Heterosexual        No   No, not at all
# 1                      NaN       Yes  Yes, definitely
# 2                      NaN       Yes    Yes, somewhat
# 3  Straight / Heterosexual       Yes  Yes, definitely
# 4  Straight / Heterosexual       Yes    Yes, somewhat
#
#                             SOPartFreq                      SOVisitFreq  \
# 0                                  NaN           Multiple times per day
# 1  Less than once per month or monthly           Multiple times per day
# 2      A few times per month or weekly            Daily or almost daily
# 3      A few times per month or weekly           Multiple times per day
# 4  Less than once per month or monthly  A few times per month or weekly
#
#                    SurveyEase           SurveyLength Trans  \
# 0  Neither easy nor difficult  Appropriate in length    No
# 1                         NaN                    NaN   NaN
# 2  Neither easy nor difficult  Appropriate in length   NaN
# 3                         NaN                    NaN    No
# 4                        Easy              Too short    No
#
#                                       UndergradMajor WebframeDesireNextYear  \
# 0  Computer science, computer engineering, or sof...           ASP.NET Core
# 1  Computer science, computer engineering, or sof...                    NaN
# 2                                                NaN                    NaN
# 3  Computer science, computer engineering, or sof...                    NaN
# 4  Computer science, computer engineering, or sof...   Django;Ruby on Rails
#
#      WebframeWorkedWith                             WelcomeChange  \
# 0  ASP.NET;ASP.NET Core   Just as welcome now as I felt last year
# 1                   NaN  Somewhat more welcome now than last year
# 2                   NaN  Somewhat more welcome now than last year
# 3                   NaN  Somewhat less welcome now than last year
# 4         Ruby on Rails   Just as welcome now as I felt last year
#
#    WorkWeekHrs YearsCode YearsCodePro
# 0         50.0        36           27
# 1          NaN         7            4
# 2          NaN         4          NaN
# 3         40.0         7            4
# 4          NaN        15            8

# %%
public_df.sort_values(by=['Country', 'ConvertedComp'], ascending=[True, False], inplace=True)

# %%
public_df[['Country', 'ConvertedComp']].head(100) # 這裡比較值得注意的是 NaN 會排在非 NaN 的資料後面
# Out:
#            Country  ConvertedComp
# 61540  Afghanistan      1000000.0
# 63925  Afghanistan      1000000.0
# 63993  Afghanistan      1000000.0
# 38261  Afghanistan       231192.0
# 28270  Afghanistan       130000.0
# 9806   Afghanistan        23328.0
# 62520  Afghanistan        23328.0
# 50812  Afghanistan        20950.0
# 50469  Afghanistan        20220.0
# 43642  Afghanistan        18660.0
# 15371  Afghanistan        18000.0
# 2918   Afghanistan        16335.0
# 26443  Afghanistan        13992.0
# 56146  Afghanistan        10884.0
# 26676  Afghanistan         8016.0
# 30451  Afghanistan         5448.0
# 30405  Afghanistan         4668.0
# 28704  Afghanistan         4509.0
# 34842  Afghanistan         4356.0
# 26758  Afghanistan         2328.0
# 33755  Afghanistan         1860.0
# 35602  Afghanistan          780.0
# 17985  Afghanistan          109.0
# 35168  Afghanistan            0.0
# 895    Afghanistan            NaN
# 5948   Afghanistan            NaN
# 7586   Afghanistan            NaN
# 7678   Afghanistan            NaN
# 8599   Afghanistan            NaN
# 8824   Afghanistan            NaN
# 9454   Afghanistan            NaN
# 9585   Afghanistan            NaN
# 10317  Afghanistan            NaN
# 23708  Afghanistan            NaN
# 24124  Afghanistan            NaN
# 24908  Afghanistan            NaN
# 26477  Afghanistan            NaN
# 26496  Afghanistan            NaN
# 26525  Afghanistan            NaN
# 29781  Afghanistan            NaN
# 30491  Afghanistan            NaN
# 31199  Afghanistan            NaN
# 35052  Afghanistan            NaN
# 35511  Afghanistan            NaN
# 35541  Afghanistan            NaN
# 36354  Afghanistan            NaN
# 36887  Afghanistan            NaN
# 37284  Afghanistan            NaN
# 37371  Afghanistan            NaN
# 37601  Afghanistan            NaN
# 38761  Afghanistan            NaN
# 39097  Afghanistan            NaN
# 39808  Afghanistan            NaN
# 41506  Afghanistan            NaN
# 41950  Afghanistan            NaN
# 42432  Afghanistan            NaN
# 43010  Afghanistan            NaN
# 43140  Afghanistan            NaN
# 43157  Afghanistan            NaN
# 43708  Afghanistan            NaN
# 43709  Afghanistan            NaN
# 43843  Afghanistan            NaN
# 44504  Afghanistan            NaN
# 44571  Afghanistan            NaN
# 45037  Afghanistan            NaN
# 45879  Afghanistan            NaN
# 50492  Afghanistan            NaN
# 50641  Afghanistan            NaN
# 50847  Afghanistan            NaN
# 51804  Afghanistan            NaN
# 53923  Afghanistan            NaN
# 54129  Afghanistan            NaN
# 56507  Afghanistan            NaN
# 57044  Afghanistan            NaN
# 59329  Afghanistan            NaN
# 61453  Afghanistan            NaN
# 61694  Afghanistan            NaN
# 62196  Afghanistan            NaN
# 62210  Afghanistan            NaN
# 62227  Afghanistan            NaN
# 64197  Afghanistan            NaN
# 64297  Afghanistan            NaN
# 64306  Afghanistan            NaN
# 64343  Afghanistan            NaN
# 23253      Albania       194580.0
# 19588      Albania        32652.0
# 13025      Albania        31788.0
# 44194      Albania        31788.0
# 10613      Albania        25944.0
# 26744      Albania        25944.0
# 17168      Albania        23316.0
# 57300      Albania        21192.0
# 59859      Albania        16860.0
# 21867      Albania        15900.0
# 28793      Albania        15900.0
# 50480      Albania        15900.0
# 23409      Albania        13776.0
# 37216      Albania        12972.0
# 562        Albania        10812.0
# 27611      Albania        10596.0

# %%
public_df['ConvertedComp'].nlargest(10) # 找出 'ConvertedComp' 中最大的前十個值 (此結果未存回原資料)
# Out:
# 5701     2000000.0
# 53175    2000000.0
# 42657    2000000.0
# 58136    2000000.0
# 45753    2000000.0
# 121      2000000.0
# 123      2000000.0
# 191      2000000.0
# 663      2000000.0
# 697      2000000.0
# Name: ConvertedComp, dtype: float64

# %%
public_df.loc[public_df['ConvertedComp'].nlargest(10).index, 'Country'] # 利用找出上面結果的 index 輸出列索引 'Country' 的元素
# Out:
# 5701            Canada
# 53175           Canada
# 42657            Italy
# 58136            Nepal
# 45753          Nomadic
# 121      United States
# 123      United States
# 191      United States
# 663      United States
# 697      United States
# Name: Country, dtype: object

# %%
public_df['ConvertedComp'].nlargest(10).index # 找出 'ConvertedComp' 中最大的前十個值的行索引 (此結果未存回原資料)
# Out:
# Int64Index([53175, 5701, 42657, 58136, 45753, 1784, 3058, 3031, 1407, 3247], dtype='int64')

# %%
public_df.nlargest(10, 'ConvertedComp') # 類似的操作但是結果不同 這邊變成搜尋條件是 'ConvertedComp' 最大的前十筆 搜尋範圍是整個資料以 'ConvertedComp' 來排序(此結果未存回原資料)
# Out:
#        Respondent                      MainBranch Hobbyist   Age  \
# 53175       54263  I am a developer by profession      Yes  29.0
# 5701         5725  I am a developer by profession       No  26.0
# 42657       43430  I am a developer by profession      Yes  33.0
# 58136       59279  I am a developer by profession      Yes   NaN
# 45753       46711  I am a developer by profession      Yes   NaN
# 1784         1793  I am a developer by profession      Yes  27.0
# 3058         3072  I am a developer by profession      Yes  32.0
# 3031         3045  I am a developer by profession      Yes  35.0
# 1407         1413  I am a developer by profession      Yes  25.0
# 3247         3261  I am a developer by profession      Yes  34.0
#
#                  Age1stCode CompFreq     CompTotal  ConvertedComp  \
# 53175                    10   Weekly  7.000000e+04      2000000.0
# 5701                     14  Monthly  1.800000e+05      2000000.0
# 42657                    17  Monthly  1.710000e+05      2000000.0
# 58136                    12  Monthly  3.000000e+05      2000000.0
# 45753  Younger than 5 years   Yearly  1.000000e+56      2000000.0
# 1784                     16   Weekly  1.200000e+05      2000000.0
# 3058                     22   Weekly  1.020000e+05      2000000.0
# 3031                     12   Weekly  1.000000e+05      2000000.0
# 1407                     12   Weekly  4.100000e+04      2000000.0
# 3247                     23   Weekly  1.150000e+05      2000000.0
#
#              Country          CurrencyDesc CurrencySymbol  \
# 53175         Canada  United States dollar            USD
# 5701          Canada  United States dollar            USD
# 42657          Italy  United States dollar            USD
# 58136          Nepal  United States dollar            USD
# 45753        Nomadic  United States dollar            USD
# 1784   United States  United States dollar            USD
# 3058   United States  United States dollar            USD
# 3031   United States  United States dollar            USD
# 1407   United States  United States dollar            USD
# 3247   United States  United States dollar            USD
#
#                                   DatabaseDesireNextYear  \
# 53175                                              Redis
# 5701                                               Redis
# 42657                                                NaN
# 58136  Cassandra;Couchbase;DynamoDB;IBM DB2;MariaDB;M...
# 45753  Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 1784                            MariaDB;PostgreSQL;Redis
# 3058                                             MongoDB
# 3031              MongoDB;MySQL;Oracle;PostgreSQL;SQLite
# 1407                          Microsoft SQL Server;MySQL
# 3247                                DynamoDB;MySQL;Redis
#
#                                       DatabaseWorkedWith  \
# 53175                         Firebase;PostgreSQL;SQLite
# 5701                                                 NaN
# 42657                                                NaN
# 58136  Elasticsearch;Firebase;Microsoft SQL Server;My...
# 45753  Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 1784                         Elasticsearch;Oracle;SQLite
# 3058                          Microsoft SQL Server;Redis
# 3031   DynamoDB;MariaDB;Microsoft SQL Server;MongoDB;...
# 1407                          Microsoft SQL Server;MySQL
# 3247                                    DynamoDB;MongoDB
#
#                                                  DevType  \
# 53175                                  Developer, mobile
# 5701               Developer, back-end;DevOps specialist
# 42657  Academic researcher;Developer, back-end;Develo...
# 58136  Data or business analyst;Data scientist or mac...
# 45753  Academic researcher;Data or business analyst;D...
# 1784                                 Developer, back-end
# 3058   Data scientist or machine learning specialist;...
# 3031   Developer, back-end;Developer, desktop or ente...
# 1407   Database administrator;Designer;Developer, bac...
# 3247   Data scientist or machine learning specialist;...
#
#                                                  EdLevel  \
# 53175       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5701        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 42657         Other doctoral degree (Ph.D., Ed.D., etc.)
# 58136    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 45753                          Primary/elementary school
# 1784        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3058     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3031        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 1407   Some college/university study without earning ...
# 3247        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                               Employment  \
# 53175                                 Employed full-time
# 5701                                  Employed full-time
# 42657                                 Employed full-time
# 58136                                 Employed full-time
# 45753                                 Employed full-time
# 1784                                  Employed full-time
# 3058                                  Employed full-time
# 3031                                  Employed full-time
# 1407                                  Employed full-time
# 3247   Independent contractor, freelancer, or self-em...
#
#                                                Ethnicity  \
# 53175                                        South Asian
# 5701                        White or of European descent
# 42657                       White or of European descent
# 58136                        South Asian;Southeast Asian
# 45753                                                NaN
# 1784                        White or of European descent
# 3058                        White or of European descent
# 3031                        White or of European descent
# 1407                        White or of European descent
# 3247   White or of European descent;South Asian;Multi...
#
#                                                   Gender  \
# 53175                                                Man
# 5701                                                 Man
# 42657                                                Man
# 58136                                                NaN
# 45753                                                NaN
# 1784                                                 Man
# 3058                                                 Man
# 3031                                                 Man
# 1407   Non-binary, genderqueer, or gender non-conforming
# 3247                                                 Man
#
#                                               JobFactors  \
# 53175  Flex time or a flexible schedule;Languages, fr...
# 5701   Languages, frameworks, and other technologies ...
# 42657  Languages, frameworks, and other technologies ...
# 58136  Flex time or a flexible schedule;Remote work o...
# 45753  Languages, frameworks, and other technologies ...
# 1784   Languages, frameworks, and other technologies ...
# 3058   Flex time or a flexible schedule;Languages, fr...
# 3031   Office environment or company culture;Opportun...
# 1407   Flex time or a flexible schedule;How widely us...
# 3247   Languages, frameworks, and other technologies ...
#
#                       JobSat  \
# 53175     Slightly satisfied
# 5701      Slightly satisfied
# 42657         Very satisfied
# 58136         Very satisfied
# 45753         Very satisfied
# 1784      Slightly satisfied
# 3058          Very satisfied
# 3031   Slightly dissatisfied
# 1407      Slightly satisfied
# 3247       Very dissatisfied
#
#                                                  JobSeek  \
# 53175  I’m not actively looking, but I am open to new...
# 5701        I am not interested in new job opportunities
# 42657       I am not interested in new job opportunities
# 58136  I’m not actively looking, but I am open to new...
# 45753  I’m not actively looking, but I am open to new...
# 1784   I’m not actively looking, but I am open to new...
# 3058   I’m not actively looking, but I am open to new...
# 3031                     I am actively looking for a job
# 1407   I’m not actively looking, but I am open to new...
# 3247                     I am actively looking for a job
#
#                                   LanguageDesireNextYear  \
# 53175                                    Go;Haskell;Rust
# 5701                           Go;Python;Ruby;TypeScript
# 42657   Assembly;Bash/Shell/PowerShell;C;C++;Perl;Python
# 58136  Dart;Go;Haskell;Julia;Kotlin;Perl;PHP;R;Ruby;R...
# 45753  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 1784                                        Dart;Go;Ruby
# 3058                                      C#;Python;Rust
# 3031   Bash/Shell/PowerShell;C#;C++;Go;HTML/CSS;Java;...
# 1407   Bash/Shell/PowerShell;HTML/CSS;JavaScript;Perl...
# 3247                     HTML/CSS;Java;JavaScript;Python
#
#                                       LanguageWorkedWith  \
# 53175      Dart;Java;JavaScript;Kotlin;Python;TypeScript
# 5701             Bash/Shell/PowerShell;JavaScript;Python
# 42657   Assembly;Bash/Shell/PowerShell;C;C++;Perl;Python
# 58136  Assembly;Bash/Shell/PowerShell;C;C#;C++;HTML/C...
# 45753  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 1784   Bash/Shell/PowerShell;C++;HTML/CSS;Python;Rust...
# 3058                                           C#;Python
# 3031   Bash/Shell/PowerShell;C;C#;C++;Go;HTML/CSS;Jav...
# 1407   Bash/Shell/PowerShell;HTML/CSS;JavaScript;Perl...
# 3247                     HTML/CSS;Java;JavaScript;Python
#
#                                   MiscTechDesireNextYear  \
# 53175              React Native;TensorFlow;Torch/PyTorch
# 5701                                            Teraform
# 42657                                                NaN
# 58136  Ansible;Apache Spark;Flutter;Hadoop;Keras;Pand...
# 45753  .NET;.NET Core;Ansible;Apache Spark;Chef;Cordo...
# 1784                                                 NaN
# 3058   .NET Core;Cordova;Pandas;TensorFlow;Torch/PyTorch
# 3031   .NET;.NET Core;Apache Spark;Hadoop;Unity 3D;Un...
# 1407                                                 NaN
# 3247                                                 NaN
#
#                                       MiscTechWorkedWith  \
# 53175                                    Flutter;Node.js
# 5701                                                 NaN
# 42657                                                NaN
# 58136  .NET;.NET Core;Chef;Cordova;Node.js;React Nati...
# 45753  .NET;.NET Core;Ansible;Apache Spark;Chef;Cordo...
# 1784                                             Ansible
# 3058                                    .NET Core;Pandas
# 3031   .NET;.NET Core;Apache Spark;Hadoop;Node.js;Uni...
# 1407                                                 NaN
# 3247                                                 NaN
#
#                             NEWCollabToolsDesireNextYear  \
# 53175                                 Facebook Workplace
# 5701        Github;Gitlab;Google Suite (Docs, Meet, etc)
# 42657  Confluence;Jira;Github;Gitlab;Slack;Google Sui...
# 58136                                      Gitlab;Trello
# 45753  Confluence;Jira;Github;Gitlab;Facebook Workpla...
# 1784                                                 NaN
# 3058   Confluence;Gitlab;Microsoft Teams;Microsoft Az...
# 3031   Github;Microsoft Teams;Microsoft Azure;Google ...
# 1407                                         Jira;Github
# 3247   Confluence;Jira;Github;Slack;Google Suite (Doc...
#
#                                 NEWCollabToolsWorkedWith NEWDevOps  \
# 53175  Confluence;Jira;Github;Gitlab;Slack;Microsoft ...       Yes
# 5701               Github;Google Suite (Docs, Meet, etc)       Yes
# 42657  Confluence;Jira;Github;Gitlab;Slack;Google Sui...       Yes
# 58136  Confluence;Jira;Github;Facebook Workplace;Slac...       Yes
# 45753  Confluence;Jira;Github;Gitlab;Facebook Workpla...       Yes
# 1784              Confluence;Jira;Github;Microsoft Teams       Yes
# 3058                   Confluence;Gitlab;Microsoft Azure       Yes
# 3031   Github;Slack;Microsoft Teams;Microsoft Azure;G...        No
# 1407                                              Github        No
# 3247   Confluence;Jira;Github;Slack;Google Suite (Doc...       Yes
#
#              NEWDevOpsImpt                           NEWEdImpt  \
# 53175  Extremely important                  Somewhat important
# 5701   Extremely important                      Very important
# 42657   Somewhat important                    Fairly important
# 58136  Extremely important                                 NaN
# 45753  Extremely important  Not at all important/not necessary
# 1784               Neutral                      Very important
# 3058   Extremely important                      Very important
# 3031    Not very important                      Very important
# 1407               Neutral                    Fairly important
# 3247   Extremely important                Critically important
#
#                                               NEWJobHunt  \
# 53175  Just because;Curious about other opportunities...
# 5701   Trouble with my teammates;Better work/life bal...
# 42657  Curious about other opportunities;Better compe...
# 58136  Having a bad day (or week or month) at work;Tr...
# 45753  Just because;Having a bad day (or week or mont...
# 1784   Just because;Having a bad day (or week or mont...
# 3058   Curious about other opportunities;Growth or le...
# 3031   Having a bad day (or week or month) at work;Wa...
# 1407   Curious about other opportunities;Better compe...
# 3247   Having a bad day (or week or month) at work;Cu...
#
#                                       NEWJobHuntResearch  \
# 53175  Read company media, such as employee blogs or ...
# 5701   Read company media, such as employee blogs or ...
# 42657  Read company media, such as employee blogs or ...
# 58136  Read company media, such as employee blogs or ...
# 45753  Read company media, such as employee blogs or ...
# 1784   Read company media, such as employee blogs or ...
# 3058   Read company media, such as employee blogs or ...
# 3031   Company reviews from third party sites (e.g. G...
# 1407   Read company media, such as employee blogs or ...
# 3247   Read company media, such as employee blogs or ...
#
#                    NEWLearn NEWOffTopic NEWOnboardGood NEWOtherComms  \
# 53175      Every few months    Not sure            Yes           Yes
# 5701            Once a year          No            Yes            No
# 42657  Once every few years    Not sure            Yes            No
# 58136                   NaN         Yes            Yes            No
# 45753      Every few months         NaN            Yes           NaN
# 1784            Once a year          No            Yes            No
# 3058            Once a year          No             No            No
# 3031       Every few months          No             No            No
# 1407                    NaN         Yes            Yes            No
# 3247   Once every few years          No             No            No
#
#                                              NEWOvertime  \
# 53175                  Rarely: 1-2 days per year or less
# 5701                    Often: 1-2 days per week or more
# 42657                   Often: 1-2 days per week or more
# 58136  Sometimes: 1-2 days per month but less than we...
# 45753                   Often: 1-2 days per week or more
# 1784                   Rarely: 1-2 days per year or less
# 3058   Sometimes: 1-2 days per month but less than we...
# 3031   Sometimes: 1-2 days per month but less than we...
# 1407   Occasionally: 1-2 days per quarter but less th...
# 3247                    Often: 1-2 days per week or more
#
#                                      NEWPurchaseResearch      NEWPurpleLink  \
# 53175  Start a free trial;Ask developers I know/work ...  Hello, old friend
# 5701                                                 NaN  Hello, old friend
# 42657                                 Start a free trial        Indifferent
# 58136  Start a free trial;Ask developers I know/work ...             Amused
# 45753                                                NaN  Hello, old friend
# 1784                                                 NaN  Hello, old friend
# 3058   Start a free trial;Ask developers I know/work ...  Hello, old friend
# 3031                                                 NaN             Amused
# 1407   Start a free trial;Ask developers I know/work ...  Hello, old friend
# 3247     Visit developer communities like Stack Overflow  Hello, old friend
#
#                                               NEWSOSites  \
# 53175  Stack Overflow (public Q&A for anyone who code...
# 5701   Stack Overflow (public Q&A for anyone who code...
# 42657   Stack Overflow (public Q&A for anyone who codes)
# 58136  Stack Overflow (public Q&A for anyone who code...
# 45753  Stack Overflow (public Q&A for anyone who code...
# 1784   Stack Overflow (public Q&A for anyone who code...
# 3058   Stack Overflow (public Q&A for anyone who code...
# 3031   Stack Overflow (public Q&A for anyone who code...
# 1407   Stack Overflow (public Q&A for anyone who code...
# 3247   Stack Overflow (public Q&A for anyone who code...
#
#                                                 NEWStuck        OpSys  \
# 53175  Meditate;Visit Stack Overflow;Go for a walk or...        MacOS
# 5701   Call a coworker or friend;Go for a walk or oth...  Linux-based
# 42657  Call a coworker or friend;Go for a walk or oth...  Linux-based
# 58136  Call a coworker or friend;Visit Stack Overflow...      Windows
# 45753  Meditate;Play games;Call a coworker or friend;...          NaN
# 1784   Call a coworker or friend;Visit Stack Overflow...  Linux-based
# 3058   Meditate;Play games;Call a coworker or friend;...      Windows
# 3031   Play games;Visit Stack Overflow;Go for a walk ...      Windows
# 1407   Play games;Call a coworker or friend;Visit Sta...      Windows
# 3247   Play games;Call a coworker or friend;Visit Sta...        MacOS
#
#                         OrgSize  \
# 53175                       NaN
# 5701   10,000 or more employees
# 42657  10,000 or more employees
# 58136  1,000 to 4,999 employees
# 45753  10,000 or more employees
# 1784   1,000 to 4,999 employees
# 3058   10,000 or more employees
# 3031       100 to 499 employees
# 1407       500 to 999 employees
# 3247       100 to 499 employees
#
#                                   PlatformDesireNextYear  \
# 53175                       Docker;Heroku;iOS;Kubernetes
# 5701                        Docker;Google Cloud Platform
# 42657                        Android;Linux;MacOS;Windows
# 58136  Arduino;Heroku;IBM Cloud or Watson;Kubernetes;...
# 45753  Android;Arduino;AWS;Docker;Google Cloud Platfo...
# 1784                                     Android;Arduino
# 3058                                Docker;Linux;Windows
# 3031   Android;AWS;iOS;Kubernetes;Linux;MacOS;Microso...
# 1407                          Linux;Raspberry Pi;Windows
# 3247                                      AWS;Kubernetes
#
#                                       PlatformWorkedWith  \
# 53175                                  Android;AWS;Linux
# 5701                        Docker;Google Cloud Platform
# 42657                        Android;Linux;MacOS;Windows
# 58136  Android;AWS;Docker;Google Cloud Platform;iOS;L...
# 45753  Android;Arduino;AWS;Docker;Google Cloud Platfo...
# 1784                           Docker;Linux;Raspberry Pi
# 3058                                Docker;Linux;Windows
# 3031     Android;AWS;Linux;MacOS;Microsoft Azure;Windows
# 1407                Linux;Raspberry Pi;Windows;WordPress
# 3247                                                 AWS
#
#                            PurchaseWhat                Sexuality  \
# 53175             I have some influence  Straight / Heterosexual
# 5701      I have little or no influence  Straight / Heterosexual
# 42657             I have some influence  Straight / Heterosexual
# 58136  I have a great deal of influence                      NaN
# 45753     I have little or no influence                      NaN
# 1784      I have little or no influence  Straight / Heterosexual
# 3058              I have some influence  Straight / Heterosexual
# 3031      I have little or no influence  Straight / Heterosexual
# 1407              I have some influence                 Bisexual
# 3247                                NaN  Straight / Heterosexual
#
#                      SOAccount           SOComm  \
# 53175  Not sure/can't remember    Yes, somewhat
# 5701                       Yes   No, not at all
# 42657                      Yes   No, not at all
# 58136                      Yes    Yes, somewhat
# 45753                      NaN              NaN
# 1784                       Yes   No, not really
# 3058                       Yes  Yes, definitely
# 3031                       Yes    Yes, somewhat
# 1407                       Yes   No, not really
# 3247                       Yes  Yes, definitely
#
#                                               SOPartFreq  \
# 53175                                                NaN
# 5701   I have never participated in Q&A on Stack Over...
# 42657  I have never participated in Q&A on Stack Over...
# 58136  I have never participated in Q&A on Stack Over...
# 45753                                                NaN
# 1784   I have never participated in Q&A on Stack Over...
# 3058                     A few times per month or weekly
# 3031                 Less than once per month or monthly
# 1407                 Less than once per month or monthly
# 3247   I have never participated in Q&A on Stack Over...
#
#                            SOVisitFreq                  SurveyEase  \
# 53175            Daily or almost daily  Neither easy nor difficult
# 5701   A few times per month or weekly                        Easy
# 42657  A few times per month or weekly                        Easy
# 58136           Multiple times per day  Neither easy nor difficult
# 45753           Multiple times per day                         NaN
# 1784             Daily or almost daily                        Easy
# 3058   A few times per month or weekly                        Easy
# 3031   A few times per month or weekly  Neither easy nor difficult
# 1407             Daily or almost daily  Neither easy nor difficult
# 3247              A few times per week                        Easy
#
#                 SurveyLength Trans  \
# 53175               Too long    No
# 5701               Too short    No
# 42657  Appropriate in length    No
# 58136               Too long   NaN
# 45753                    NaN   NaN
# 1784   Appropriate in length    No
# 3058   Appropriate in length    No
# 3031                Too long    No
# 1407   Appropriate in length    No
# 3247   Appropriate in length    No
#
#                                           UndergradMajor  \
# 53175  Computer science, computer engineering, or sof...
# 5701   Computer science, computer engineering, or sof...
# 42657  Computer science, computer engineering, or sof...
# 58136  Computer science, computer engineering, or sof...
# 45753                                                NaN
# 1784   Computer science, computer engineering, or sof...
# 3058   Computer science, computer engineering, or sof...
# 3031   Computer science, computer engineering, or sof...
# 1407   Computer science, computer engineering, or sof...
# 3247   Computer science, computer engineering, or sof...
#
#                                   WebframeDesireNextYear  \
# 53175                                    React.js;Vue.js
# 5701                                              Gatsby
# 42657                                                NaN
# 58136                 Django;Drupal;Flask;Gatsby;Laravel
# 45753  Angular;Angular.js;ASP.NET;ASP.NET Core;Django...
# 1784                                                 NaN
# 3058                                  ASP.NET Core;Flask
# 3031   Angular;Angular.js;ASP.NET;ASP.NET Core;Django...
# 1407                                      jQuery;Laravel
# 3247                                Django;jQuery;Spring
#
#                                       WebframeWorkedWith  \
# 53175                               Express;Flask;jQuery
# 5701                                              Spring
# 42657                                                NaN
# 58136  Angular;Angular.js;ASP.NET;ASP.NET Core;Expres...
# 45753  Angular;Angular.js;ASP.NET;ASP.NET Core;Django...
# 1784                                                 NaN
# 3058                                        ASP.NET Core
# 3031   Angular;Angular.js;ASP.NET;ASP.NET Core;Django...
# 1407                                              jQuery
# 3247                                              Spring
#
#                                            WelcomeChange  WorkWeekHrs  \
# 53175            Just as welcome now as I felt last year         36.0
# 5701   Not applicable - I did not use Stack Overflow ...         40.0
# 42657            Just as welcome now as I felt last year         40.0
# 58136              A lot more welcome now than last year         40.0
# 45753                                                NaN        168.0
# 1784             Just as welcome now as I felt last year         40.0
# 3058            Somewhat less welcome now than last year         40.0
# 3031             Just as welcome now as I felt last year         42.0
# 1407             Just as welcome now as I felt last year         37.0
# 3247             Just as welcome now as I felt last year         60.0
#
#                 YearsCode        YearsCodePro
# 53175                  14                   5
# 5701                   10                   4
# 42657                  13                   2
# 58136                  20                  14
# 45753  More than 50 years  More than 50 years
# 1784                   12                 NaN
# 3058                   10                   7
# 3031                   23                   5
# 1407                   13                   3
# 3247                   11                   9

# %%
public_df.nsmallest(10, 'ConvertedComp') # 這裡值得注意的是 找最小值並不會回傳 NaN (找最大值也不會)
# Out:
#        Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 35168       35295  I am a developer by profession      Yes   NaN         13
# 46385       47357  I am a developer by profession      Yes   NaN          5
# 27035       27135  I am a developer by profession       No   NaN         16
# 6029         6054  I am a developer by profession      Yes  38.0         15
# 59118       60292  I am a developer by profession      Yes   NaN         12
# 38395       38813  I am a developer by profession       No   NaN         18
# 8438         8470  I am a developer by profession      Yes   NaN          5
# 40410       41006  I am a developer by profession      Yes  22.0         17
# 15442       15493  I am a developer by profession       No  44.0         17
# 56246       57369  I am a developer by profession       No  44.0         18
#
#       CompFreq  CompTotal  ConvertedComp      Country        CurrencyDesc  \
# 35168  Monthly        2.0            0.0  Afghanistan      Afghan afghani
# 46385   Weekly        1.0            0.0      Albania  Bhutanese ngultrum
# 27035   Yearly        0.0            0.0    Australia   Australian dollar
# 6029    Yearly        0.0            0.0    Australia   Australian dollar
# 59118   Yearly        0.0            0.0      Austria       European Euro
# 38395  Monthly        0.0            0.0   Azerbaijan    Azerbaijan manat
# 8438   Monthly       30.0            0.0   Bangladesh    Bangladeshi taka
# 40410   Yearly        0.0            0.0      Belgium      Pound sterling
# 15442  Monthly        0.0            0.0       Brazil      Brazilian real
# 56246  Monthly        0.0            0.0       Brazil      Brazilian real
#
#       CurrencySymbol                             DatabaseDesireNextYear  \
# 35168            AFN                                                NaN
# 46385            BTN                                            MariaDB
# 27035            AUD                                              MySQL
# 6029             AUD                                                NaN
# 59118            EUR                                                NaN
# 38395            AZN                                                NaN
# 8438             BDT  Elasticsearch;Firebase;MongoDB;MySQL;PostgreSQ...
# 40410            GBP                                                NaN
# 15442            BRL                                           DynamoDB
# 56246            BRL                                           DynamoDB
#
#                                    DatabaseWorkedWith  \
# 35168                         MySQL;PostgreSQL;SQLite
# 46385                                             NaN
# 27035                                           MySQL
# 6029                                            MySQL
# 59118                                             NaN
# 38395                                             NaN
# 8438   Firebase;MongoDB;MySQL;Oracle;PostgreSQL;Redis
# 40410                            Firebase;MySQL;Redis
# 15442                                        DynamoDB
# 56246                                DynamoDB;MongoDB
#
#                                                  DevType  \
# 35168             Academic researcher;Educator;Scientist
# 46385                                Academic researcher
# 27035                                Senior executive/VP
# 6029   Designer;Developer, back-end;Developer, front-...
# 59118                                                NaN
# 38395  Academic researcher;Data or business analyst;D...
# 8438   Developer, back-end;Developer, front-end;Devel...
# 40410  Developer, back-end;Developer, desktop or ente...
# 15442  Developer, back-end;Developer, front-end;Devel...
# 56246                              Developer, full-stack
#
#                                                  EdLevel  \
# 35168         Other doctoral degree (Ph.D., Ed.D., etc.)
# 46385                          Primary/elementary school
# 27035    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 6029   Secondary school (e.g. American high school, G...
# 59118         Other doctoral degree (Ph.D., Ed.D., etc.)
# 38395    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 8438        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 40410  Some college/university study without earning ...
# 15442       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 56246       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                               Employment  \
# 35168  Independent contractor, freelancer, or self-em...
# 46385                                 Employed full-time
# 27035  Independent contractor, freelancer, or self-em...
# 6029   Independent contractor, freelancer, or self-em...
# 59118                                 Employed full-time
# 38395                                 Employed full-time
# 8438                                  Employed full-time
# 40410  Independent contractor, freelancer, or self-em...
# 15442  Independent contractor, freelancer, or self-em...
# 56246                                 Employed full-time
#
#                           Ethnicity Gender  \
# 35168                           NaN    NaN
# 46385                           NaN    NaN
# 27035                           NaN    Man
# 6029                            NaN    Man
# 59118                           NaN    NaN
# 38395                           NaN    NaN
# 8438                            NaN    Man
# 40410                Middle Eastern    Man
# 15442  White or of European descent    Man
# 56246                Middle Eastern    Man
#
#                                               JobFactors  \
# 35168                                                NaN
# 46385                                Family friendliness
# 27035  Industry that I’d be working in;How widely use...
# 6029   Flex time or a flexible schedule;Languages, fr...
# 59118                                                NaN
# 38395                                                NaN
# 8438                                                 NaN
# 40410  Languages, frameworks, and other technologies ...
# 15442  Flex time or a flexible schedule;Languages, fr...
# 56246  Flex time or a flexible schedule;Languages, fr...
#
#                                    JobSat  \
# 35168                   Very dissatisfied
# 46385  Neither satisfied nor dissatisfied
# 27035                      Very satisfied
# 6029                       Very satisfied
# 59118                                 NaN
# 38395                   Very dissatisfied
# 8438                                  NaN
# 40410                  Slightly satisfied
# 15442                      Very satisfied
# 56246                      Very satisfied
#
#                                                  JobSeek  \
# 35168                    I am actively looking for a job
# 46385                    I am actively looking for a job
# 27035  I’m not actively looking, but I am open to new...
# 6029        I am not interested in new job opportunities
# 59118                                                NaN
# 38395                                                NaN
# 8438   I’m not actively looking, but I am open to new...
# 40410  I’m not actively looking, but I am open to new...
# 15442  I’m not actively looking, but I am open to new...
# 56246  I’m not actively looking, but I am open to new...
#
#                                   LanguageDesireNextYear  \
# 35168                                                NaN
# 46385                            Bash/Shell/PowerShell;C
# 27035                  Go;HTML/CSS;JavaScript;Python;SQL
# 6029                                                 NaN
# 59118                                                NaN
# 38395                                                NaN
# 8438   Bash/Shell/PowerShell;Dart;Go;JavaScript;Pytho...
# 40410                          C++;Go;Kotlin;Python;Rust
# 15442                                         JavaScript
# 56246                                         JavaScript
#
#                                       LanguageWorkedWith  \
# 35168  Assembly;Bash/Shell/PowerShell;C;C++;Java;Java...
# 46385                                                NaN
# 27035           HTML/CSS;JavaScript;PHP;Python;R;SQL;VBA
# 6029                                                 PHP
# 59118                                                NaN
# 38395                                                NaN
# 8438   Assembly;Bash/Shell/PowerShell;C;HTML/CSS;Java...
# 40410  Bash/Shell/PowerShell;C#;HTML/CSS;Java;JavaScr...
# 15442                                HTML/CSS;JavaScript
# 56246                                         JavaScript
#
#                                   MiscTechDesireNextYear  \
# 35168                                                NaN
# 46385                                             Hadoop
# 27035  Apache Spark;Node.js;Pandas;TensorFlow;Torch/P...
# 6029                                                 NaN
# 59118                                                NaN
# 38395                                                NaN
# 8438             Flutter;Node.js;React Native;TensorFlow
# 40410                            React Native;TensorFlow
# 15442                      Node.js;React Native;Teraform
# 56246                      Node.js;React Native;Teraform
#
#                                       MiscTechWorkedWith  \
# 35168                                TensorFlow;Unity 3D
# 46385                                                NaN
# 27035  Apache Spark;Node.js;Pandas;TensorFlow;Torch/P...
# 6029                                                 NaN
# 59118                                                NaN
# 38395                                                NaN
# 8438                                             Node.js
# 40410                                  .NET Core;Node.js
# 15442                                            Node.js
# 56246                                            Node.js
#
#                             NEWCollabToolsDesireNextYear  \
# 35168                                                NaN
# 46385                     Google Suite (Docs, Meet, etc)
# 27035                                 Jira;Github;Trello
# 6029                                                 NaN
# 59118                                                NaN
# 38395                                                NaN
# 8438   Jira;Github;Gitlab;Slack;Trello;Google Suite (...
# 40410                                                NaN
# 15442                          Github;Facebook Workplace
# 56246  Github;Gitlab;Facebook Workplace;Trello;Stack ...
#
#                                 NEWCollabToolsWorkedWith NEWDevOps  \
# 35168                                                NaN       NaN
# 46385                                                NaN        No
# 27035                                 Jira;Github;Trello        No
# 6029                                                 NaN        No
# 59118                                                NaN       NaN
# 38395                                                NaN       NaN
# 8438   Jira;Github;Gitlab;Slack;Trello;Google Suite (...        No
# 40410  Github;Gitlab;Trello;Google Suite (Docs, Meet,...        No
# 15442                                Github;Slack;Trello        No
# 56246  Github;Slack;Trello;Google Suite (Docs, Meet, ...        No
#
#              NEWDevOpsImpt                           NEWEdImpt  \
# 35168                  NaN                      Very important
# 46385  Extremely important                  Somewhat important
# 27035  Extremely important                    Fairly important
# 6029               Neutral  Not at all important/not necessary
# 59118                  NaN                    Fairly important
# 38395                  NaN                Critically important
# 8438   Extremely important                                 NaN
# 40410  Extremely important  Not at all important/not necessary
# 15442  Extremely important                  Somewhat important
# 56246   Somewhat important                  Somewhat important
#
#                                               NEWJobHunt  \
# 35168                                                NaN
# 46385                                       Just because
# 27035  Curious about other opportunities;Better compe...
# 6029                                                 NaN
# 59118                                                NaN
# 38395                                                NaN
# 8438   Curious about other opportunities;Better compe...
# 40410                                                NaN
# 15442  Curious about other opportunities;Better compe...
# 56246  Curious about other opportunities;Better compe...
#
#                                       NEWJobHuntResearch  \
# 35168                                                NaN
# 46385  Read company media, such as employee blogs or ...
# 27035  Read company media, such as employee blogs or ...
# 6029                                                 NaN
# 59118                                                NaN
# 38395                                                NaN
# 8438                                                 NaN
# 40410  Read company media, such as employee blogs or ...
# 15442  Company reviews from third party sites (e.g. G...
# 56246  Read company media, such as employee blogs or ...
#
#                    NEWLearn NEWOffTopic                NEWOnboardGood  \
# 35168           Once a year         Yes  Onboarding? What onboarding?
# 46385         Once a decade         NaN                           Yes
# 27035      Every few months    Not sure  Onboarding? What onboarding?
# 6029   Once every few years    Not sure  Onboarding? What onboarding?
# 59118                   NaN         NaN                           NaN
# 38395                   NaN    Not sure                           NaN
# 8438       Every few months         NaN                           NaN
# 40410      Every few months    Not sure  Onboarding? What onboarding?
# 15442         Once a decade          No                            No
# 56246         Once a decade          No                            No
#
#       NEWOtherComms                                        NEWOvertime  \
# 35168           Yes                   Often: 1-2 days per week or more
# 46385            No                  Rarely: 1-2 days per year or less
# 27035            No                   Often: 1-2 days per week or more
# 6029            Yes                   Often: 1-2 days per week or more
# 59118           NaN                                                NaN
# 38395           Yes                                                NaN
# 8438            Yes  Occasionally: 1-2 days per quarter but less th...
# 40410            No                   Often: 1-2 days per week or more
# 15442           Yes                   Often: 1-2 days per week or more
# 56246           Yes                   Often: 1-2 days per week or more
#
#                                      NEWPurchaseResearch      NEWPurpleLink  \
# 35168  Read ratings or reviews on third party sites l...  Hello, old friend
# 46385  Start a free trial;Ask developers I know/work ...  Hello, old friend
# 27035  Start a free trial;Visit developer communities...        Indifferent
# 6029                                                 NaN        Indifferent
# 59118                                                NaN                NaN
# 38395                                                NaN                NaN
# 8438                                  Start a free trial                NaN
# 40410  Read ratings or reviews on third party sites l...        Indifferent
# 15442  Start a free trial;Ask developers I know/work ...  Hello, old friend
# 56246  Start a free trial;Visit developer communities...        Indifferent
#
#                                               NEWSOSites  \
# 35168  Stack Overflow (public Q&A for anyone who code...
# 46385   Stack Overflow (public Q&A for anyone who codes)
# 27035  Stack Overflow (public Q&A for anyone who code...
# 6029   Stack Overflow (public Q&A for anyone who code...
# 59118                                                NaN
# 38395  Stack Overflow (public Q&A for anyone who code...
# 8438    Stack Overflow (public Q&A for anyone who codes)
# 40410  Stack Overflow (public Q&A for anyone who code...
# 15442   Stack Overflow (public Q&A for anyone who codes)
# 56246   Stack Overflow (public Q&A for anyone who codes)
#
#                                                 NEWStuck        OpSys  \
# 35168  Play games;Go for a walk or other physical act...  Linux-based
# 46385                                         Play games  Linux-based
# 27035  Play games;Visit Stack Overflow;Go for a walk ...      Windows
# 6029                                                 NaN        MacOS
# 59118                                                NaN          NaN
# 38395                                                NaN          NaN
# 8438                                                 NaN        MacOS
# 40410  Visit Stack Overflow;Panic;Do other work and c...  Linux-based
# 15442  Call a coworker or friend;Visit Stack Overflow...      Windows
# 56246  Call a coworker or friend;Visit Stack Overflow...      Windows
#
#                                                  OrgSize  \
# 35168  Just me - I am a freelancer, sole proprietor, ...
# 46385  Just me - I am a freelancer, sole proprietor, ...
# 27035                                   2 to 9 employees
# 6029   Just me - I am a freelancer, sole proprietor, ...
# 59118                           10,000 or more employees
# 38395                                   2 to 9 employees
# 8438                                  20 to 99 employees
# 40410  Just me - I am a freelancer, sole proprietor, ...
# 15442  Just me - I am a freelancer, sole proprietor, ...
# 56246  Just me - I am a freelancer, sole proprietor, ...
#
#                                   PlatformDesireNextYear  \
# 35168                                                NaN
# 46385                                                AWS
# 27035                               Raspberry Pi;Windows
# 6029                                                 NaN
# 59118                                                NaN
# 38395                                                NaN
# 8438   Android;Arduino;AWS;Docker;Google Cloud Platfo...
# 40410                          Android;iOS;MacOS;Windows
# 15442                          AWS;Google Cloud Platform
# 56246                                                AWS
#
#                                   PlatformWorkedWith  \
# 35168                        Android;iOS;Linux;MacOS
# 46385                                            NaN
# 27035     Google Cloud Platform;Raspberry Pi;Windows
# 6029                                           MacOS
# 59118                                            NaN
# 38395                                            NaN
# 8438                       Docker;Heroku;Linux;MacOS
# 40410  Docker;Google Cloud Platform;Kubernetes;Linux
# 15442                                            AWS
# 56246                                            AWS
#
#                            PurchaseWhat                Sexuality SOAccount  \
# 35168                               NaN                      NaN       Yes
# 46385                               NaN                      NaN       Yes
# 27035                               NaN                      NaN       Yes
# 6029                                NaN                      NaN       Yes
# 59118                               NaN                      NaN       NaN
# 38395                               NaN                      NaN       Yes
# 8438                                NaN                      NaN       Yes
# 40410                               NaN                 Bisexual       Yes
# 15442                               NaN  Straight / Heterosexual       Yes
# 56246  I have a great deal of influence  Straight / Heterosexual       Yes
#
#                 SOComm                                         SOPartFreq  \
# 35168   No, not at all                Less than once per month or monthly
# 46385   No, not at all                              Daily or almost daily
# 27035   No, not really  I have never participated in Q&A on Stack Over...
# 6029   Yes, definitely                Less than once per month or monthly
# 59118              NaN                                                NaN
# 38395    Yes, somewhat                Less than once per month or monthly
# 8438     Yes, somewhat                Less than once per month or monthly
# 40410          Neutral                    A few times per month or weekly
# 15442    Yes, somewhat  I have never participated in Q&A on Stack Over...
# 56246    Yes, somewhat  I have never participated in Q&A on Stack Over...
#
#                            SOVisitFreq                  SurveyEase  \
# 35168           Multiple times per day  Neither easy nor difficult
# 46385  A few times per month or weekly                         NaN
# 27035             A few times per week  Neither easy nor difficult
# 6029            Multiple times per day                        Easy
# 59118                              NaN                         NaN
# 38395           Multiple times per day                         NaN
# 8438            Multiple times per day  Neither easy nor difficult
# 40410            Daily or almost daily                        Easy
# 15442            Daily or almost daily                        Easy
# 56246           Multiple times per day                        Easy
#
#                 SurveyLength Trans  \
# 35168  Appropriate in length   NaN
# 46385                    NaN   NaN
# 27035  Appropriate in length    No
# 6029                Too long    No
# 59118                    NaN   NaN
# 38395                    NaN   NaN
# 8438   Appropriate in length    No
# 40410  Appropriate in length    No
# 15442  Appropriate in length    No
# 56246               Too long    No
#
#                                           UndergradMajor  \
# 35168  Another engineering discipline (such as civil,...
# 46385                                                NaN
# 27035  A humanities discipline (such as literature, h...
# 6029                                                 NaN
# 59118  Computer science, computer engineering, or sof...
# 38395  Computer science, computer engineering, or sof...
# 8438   Computer science, computer engineering, or sof...
# 40410  A business discipline (such as accounting, fin...
# 15442  A business discipline (such as accounting, fin...
# 56246  A business discipline (such as accounting, fin...
#
#                          WebframeDesireNextYear  \
# 35168                                       NaN
# 46385                                    Drupal
# 27035  Angular.js;Django;jQuery;React.js;Vue.js
# 6029                                        NaN
# 59118                                       NaN
# 38395                                       NaN
# 8438     Express;Gatsby;Laravel;React.js;Vue.js
# 40410                                       NaN
# 15442                                  React.js
# 56246                                  React.js
#
#                                   WebframeWorkedWith  \
# 35168                                         jQuery
# 46385                                            NaN
# 27035                         Django;jQuery;React.js
# 6029                                         Laravel
# 59118                                            NaN
# 38395                                            NaN
# 8438   Django;Express;Gatsby;Laravel;React.js;Vue.js
# 40410           Angular;ASP.NET Core;React.js;Spring
# 15442                                       React.js
# 56246                                       React.js
#
#                                   WelcomeChange  WorkWeekHrs YearsCode  \
# 35168     A lot less welcome now than last year        100.0        35
# 46385  Somewhat less welcome now than last year        168.0         2
# 27035   Just as welcome now as I felt last year         80.0        15
# 6029      A lot less welcome now than last year         30.0        22
# 59118                                       NaN          NaN        18
# 38395     A lot more welcome now than last year          NaN         4
# 8438                                        NaN          NaN         4
# 40410   Just as welcome now as I felt last year         30.0         4
# 15442   Just as welcome now as I felt last year         60.0        10
# 56246   Just as welcome now as I felt last year         60.0        10
#
#       YearsCodePro
# 35168           27
# 46385           11
# 27035           15
# 6029            20
# 59118           10
# 38395            3
# 8438             2
# 40410            3
# 15442            4
# 56246            5
